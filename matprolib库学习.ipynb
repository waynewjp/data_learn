# %% [markdown]
# # 一、PLT基本绘图
# ``` plt.plot(x,y,format_string,**kwarges) ```
# * x:X轴数据，列表或者数组。x数据可以不给，会以y轴数据的序号作为x轴
# * y:y轴数据
# * format_string:曲线格式字符串，可选
# * **kwargs:第二组或者更多上面的参数

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([3,1,4,5,2])
# 输入的一维数组是Y轴，X轴是元素的索引，【0，1，2，3，4】
plt.ylabel('grade')
plt.show()
plt.savefig('/home/www/jupyter_lab/素材/test',dpi=600) #默认是png格式

# %% [markdown]
# * 中文显示

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family']='SimHei'
matplotlib.rcParams['font.size']=20

#两个参数，一个x，一个y
plt.plot([0,2,4,6,8],[3,1,4,5,2])
plt.ylabel('成绩',fontpro)
#axis设定横纵坐标尺度：-1,10表示x轴坐标从-1到10，0,6表示y轴从0-6
plt.axis([-1,10,0,6])
plt.show()
# Out:
# findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans.

# %%
import numpy as np
import matplotlib.pyplot as plt

a=np.arange(10)
plt.plot(a,a*1.5,a,a*2.5,a,a*5.5)
plt.show()

# %% [markdown]
# # 二、绘图区域，多个图形绘制
# ``` plt.subplot(nrows,ncols,plot_number) ```
# * nrows:数字，表示将区域横轴数量
# * ncols：表示该区域纵轴数量
# * number:表示当前绘图是坐标轴中的哪个区域

# %%
import numpy as np
import matplotlib.pyplot as plt

a=np.arange(0.0,5.0,0.02)

plt.subplot(211)
plt.plot(a,np.sin(a))
plt.subplot(2,1,2)
plt.plot(a,np.cos(a),'r--')
plt.show()

# %% [markdown]
# * 子绘图区域
# * plt.subplot2grid(gridspee,curspec,colspan=1,rowspan=1)
# * 设计网格，选中网格，确定选中行列区域数量，编号从0开始
# ```
# plt.subplot2grid((3,3),(1,0),colspan=2)
# (3,3)表示将一个区域分割成3行3列，9块，从0开始
# （1，0）表示当前选中的区域。从0开始
# colspan表示长度，列占2格
# ```

# %% [markdown]
# # 三、文本显示
# * plt.xlable()  对x轴增加文本标签
# * plt.ylable()  y
# * plt.title()
# * plt.text()    对任意位置增加
# * plt.annotate()  对图形增加待箭头的注释

# %%
import numpy as np
import matplotlib.pyplot as plt

a=np.arange(0.0,5.0,0.02)
plt.plot(a,np.cos(2*np.pi*a),'r--')
plt.xlabel('横轴：时间',fontproperties='SimHei',fontsize=15,color='green')
plt.ylabel('纵轴：振幅',fontproperties='SimHei',fontsize=15)
plt.title(r'郑泫渤')
plt.show()

# %% [markdown]
# # 四、图表函数
# * plt(x,y,fmt...) 坐标
# * boxplot(data,notch,position) 箱型图
# * bar(left,height,width,botton) 条形图
# * barh(width,botton,left,height) 横向条形图
# * polar(theta,r) 极坐标
# * pic(data,explode) 饼图
# * psd() 功率谱密度图
# * specgram() 谱图
# ...累死了太多，到时候查
# ## 1.饼图

# %%
import matplotlib.pyplot as plt
labels='frog','dog','log','hog'
size=[15,30,45,10] #比例
explode=(0,0.1,0,0) #那一块要吐出来

plt.pie(size,explode=explode,labels=labels,autopct='%1.1f%%',shadow=False,startangle=90)
plt.axis('equal') # 饼图变成正圆形
plt.show()

# %% [markdown]
# ## 2.直方图

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(0)
mu,sigma=100,20 #均值、标准差
a=np.random.normal(mu,sigma,size=100)

plt.hist(a,40) # bin,直方的个数，越多越细
plt.title('test gram')

plt.show()
