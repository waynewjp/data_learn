# %% [markdown]
# # 一、PLT基本绘图
# ``` plt.plot(x,y,format_string,**kwarges) ```
# * x:X轴数据，列表或者数组。x数据可以不给，会以y轴数据的序号作为x轴
# * y:y轴数据
# * format_string:曲线格式字符串，可选
# * **kwargs:第二组或者更多上面的参数

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([3,1,4,5,2])
# 输入的一维数组是Y轴，X轴是元素的索引，【0，1，2，3，4】
plt.ylabel('grade')
plt.show()
plt.savefig('/home/www/jupyter_lab/素材/test',dpi=600) #默认是png格式

# %% [markdown]
# * 中文显示

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family']='SimHei'
matplotlib.rcParams['font.size']=20

#两个参数，一个x，一个y
plt.plot([0,2,4,6,8],[3,1,4,5,2])
plt.ylabel('成绩',fontpro)
#axis设定横纵坐标尺度：-1,10表示x轴坐标从-1到10，0,6表示y轴从0-6
plt.axis([-1,10,0,6])
plt.show()
# Out:
# findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans.

# %%
import numpy as np
import matplotlib.pyplot as plt

a=np.arange(10)
plt.plot(a,a*1.5,a,a*2.5,a,a*5.5)
plt.show()

# %% [markdown]
# # 二、绘图区域，多个图形绘制
# ``` plt.subplot(nrows,ncols,plot_number) ```
# * nrows:数字，表示将区域横轴数量
# * ncols：表示该区域纵轴数量
# * number:表示当前绘图是坐标轴中的哪个区域

# %%
import numpy as np
import matplotlib.pyplot as plt

a=np.arange(0.0,5.0,0.02)

plt.subplot(211)
plt.plot(a,np.sin(a))
plt.subplot(2,1,2)
plt.plot(a,np.cos(a),'r--')
plt.show()

# %% [markdown]
# # 三、文本显示
# * plt.xlable()  对x轴增加文本标签
# * plt.ylable()  y
# * plt.title()
# * plt.text()    对任意位置增加
# * plt.annotate()  对图形增加待箭头的注释

# %%
import numpy as np
import matplotlib.pyplot as plt

a=np.arange(0.0,5.0,0.02)
plt.plot(a,np.cos(2*np.pi*a),'r--')

# %%
plt.xlabel('横轴：时间',fontproperties='SimHei',fontsize=15,color='green')
# Out:
# Text(0.5, 0, '横轴：时间')
# findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans.
# /home/www/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 27178 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/www/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 36724 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/www/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 65306 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/www/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 26102 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/www/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 38388 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/www/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 27178 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/www/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 36724 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/www/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 65306 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/www/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 26102 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/www/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 38388 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import matplotlib    
print(matplotlib.matplotlib_fname())
# Out:
# /home/www/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/matplotlibrc
